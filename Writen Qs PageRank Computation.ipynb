# %%
import numpy as np
W = np.array([[0,0,0,0],[1/2,0,0,0],[1/2,1/2,0,0],[0,1/2,1,1]])
c = 0.8
p = np.array([1/4,1/4,1/4,1/4])

for k in range(24):
  print(f'k = {k} \np = {p}\n')
  p = c*np.matmul(W,p)+(1-c)/4*np.array([1,1,1,1])
# Out:
# k = 0
# p = [0.25 0.25 0.25 0.25]
#
# k = 1
# p = [0.05 0.15 0.25 0.55]
#
# k = 2
# p = [0.05 0.07 0.13 0.75]
#
# k = 3
# p = [0.05  0.07  0.098 0.782]
#
# k = 4
# p = [0.05  0.07  0.098 0.782]
#
# k = 5
# p = [0.05  0.07  0.098 0.782]
#
# k = 6
# p = [0.05  0.07  0.098 0.782]
#
# k = 7
# p = [0.05  0.07  0.098 0.782]
#
# k = 8
# p = [0.05  0.07  0.098 0.782]
#
# k = 9
# p = [0.05  0.07  0.098 0.782]
#
# k = 10
# p = [0.05  0.07  0.098 0.782]
#
# k = 11
# p = [0.05  0.07  0.098 0.782]
#
# k = 12
# p = [0.05  0.07  0.098 0.782]
#
# k = 13
# p = [0.05  0.07  0.098 0.782]
#
# k = 14
# p = [0.05  0.07  0.098 0.782]
#
# k = 15
# p = [0.05  0.07  0.098 0.782]
#
# k = 16
# p = [0.05  0.07  0.098 0.782]
#
# k = 17
# p = [0.05  0.07  0.098 0.782]
#
# k = 18
# p = [0.05  0.07  0.098 0.782]
#
# k = 19
# p = [0.05  0.07  0.098 0.782]
#
# k = 20
# p = [0.05  0.07  0.098 0.782]
#
# k = 21
# p = [0.05  0.07  0.098 0.782]
#
# k = 22
# p = [0.05  0.07  0.098 0.782]
#
# k = 23
# ...
